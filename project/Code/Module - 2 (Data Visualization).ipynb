# %% [markdown]
# # VISUALIZATION

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('hospital.csv')

# %%
data
# Out:
#       outcome  age        BMI  heart rate  Systolic blood pressure
# 0         0.0   72  37.588179   68.837838               155.866667  \
# 1         0.0   75        NaN  101.370370               140.000000
# 2         0.0   83  26.572634   72.318182               135.333333
# 3         0.0   43  83.264629   94.500000               126.400000
# 4         0.0   75  31.824842   67.920000               156.560000
# ...       ...  ...        ...         ...                      ...
# 1172      0.0   62  25.516870  100.125000               142.545455
# 1173      0.0   78  25.822710  114.640000               101.222222
# 1174      0.0   85  23.891779   52.720000               137.791667
# 1175      0.0   79  35.288554   93.400000                94.416667
# 1176      0.0   47  23.121384   67.289855               131.523077
#
#       Diastolic blood pressure  Respiratory rate  temperature      SP O2
# 0                    68.333333         16.621622    36.714286  98.394737  \
# 1                    65.000000         20.851852    36.682540  96.923077
# 2                    61.375000         23.640000    36.453704  95.291667
# 3                    73.200000         21.857143    36.287037  93.846154
# 4                    58.120000         21.360000    36.761905  99.280000
# ...                        ...               ...          ...        ...
# 1172                 69.681818         24.500000    37.055556  94.130435
# 1173                 51.888889         18.958333    35.972222  93.526316
# 1174                 40.958333         18.680000    36.777778  98.800000
# 1175                 62.458333         22.040000    36.422222  99.560000
# 1176                 72.276923         23.464789    37.716667  99.652174
#
#       Urine output     glucose     PH
# 0           2155.0  114.636364  7.230
# 1           1425.0  147.500000  7.225
# 2           2425.0  149.000000  7.268
# 3           8760.0  128.250000  7.370
# 4           4455.0  145.750000  7.250
# ...            ...         ...    ...
# 1172           NaN  120.000000    NaN
# 1173           NaN  138.333333    NaN
# 1174         118.0   99.000000    NaN
# 1175        2585.0  135.166667    NaN
# 1176           NaN  108.428571    NaN
#
# [1177 rows x 12 columns]

# %%
df=data.dropna()

# %%
df
# Out:
#       outcome  age        BMI  heart rate  Systolic blood pressure
# 0         0.0   72  37.588179   68.837838               155.866667  \
# 2         0.0   83  26.572634   72.318182               135.333333
# 3         0.0   43  83.264629   94.500000               126.400000
# 4         0.0   75  31.824842   67.920000               156.560000
# 5         0.0   76  24.262293   74.181818               118.100000
# ...       ...  ...        ...         ...                      ...
# 1155      0.0   83  21.551321   66.320000               111.160000
# 1156      0.0   78  19.580651   70.863636               131.904762
# 1158      0.0   82  28.950609   79.791667               104.064516
# 1164      1.0   76  26.197235   90.000000               103.440000
# 1169      0.0   88  26.571482  110.166667               120.380952
#
#       Diastolic blood pressure  Respiratory rate  temperature      SP O2
# 0                    68.333333         16.621622    36.714286  98.394737  \
# 2                    61.375000         23.640000    36.453704  95.291667
# 3                    73.200000         21.857143    36.287037  93.846154
# 4                    58.120000         21.360000    36.761905  99.280000
# 5                    52.950000         20.545455    35.266667  96.818182
# ...                        ...               ...          ...        ...
# 1155                 50.440000         18.440000    35.796296  95.000000
# 1156                 50.142857         15.652174    36.194445  97.045455
# 1158                 44.483871         21.166667    36.555556  96.761905
# 1164                 58.560000         18.428571    36.293650  98.964286
# 1169                 62.047619         25.083333    36.800000  93.333333
#
#       Urine output     glucose     PH
# 0           2155.0  114.636364  7.230
# 2           2425.0  149.000000  7.268
# 3           8760.0  128.250000  7.370
# 4           4455.0  145.750000  7.250
# 5           1840.0   98.333333  7.310
# ...            ...         ...    ...
# 1155        1845.0  262.000000  7.310
# 1156        1715.0   93.000000  7.460
# 1158        1812.0  160.250000  7.430
# 1164        1825.0   89.000000  7.240
# 1169         805.0  143.285714  7.490
#
# [709 rows x 12 columns]

# %%
df=df.rename({'heart rate': 'heart_rate','Systolic blood pressure' :'Systolic_blood_pressure'
            ,'Diastolic blood pressure':  'Diastolic_blood_pressure','Respiratory rate':'Respiratory_rate',
              'SP O2': 'SP_O2','Urine output': 'Urine_output'},axis=1)

# %%
df.columns
# Out:
# Index(['outcome', 'age', 'BMI', 'heart_rate', 'Systolic_blood_pressure',
#        'Diastolic_blood_pressure', 'Respiratory_rate', 'temperature', 'SP_O2',
#        'Urine_output', 'glucose', 'PH'],
#       dtype='object')

# %%
pd.crosstab(df.heart_rate,df.temperature)
# Out:
# temperature  33.250000  34.150725  34.324074  34.605556  34.672223  34.893519
# heart_rate
# 36.000000            0          0          0          0          0          0  \
# 39.321429            0          0          0          0          0          0
# 49.000000            0          0          0          0          0          0
# 49.695652            0          0          0          0          0          0
# 50.250000            0          0          0          0          0          0
# ...                ...        ...        ...        ...        ...        ...
# 125.769231           0          0          0          0          0          0
# 126.379310           0          0          0          0          0          0
# 133.068965           0          0          0          0          0          0
# 134.565217           0          0          0          0          0          0
# 135.708333           0          0          0          0          0          0
#
# temperature  35.086667  35.266667  35.314815  35.365079  ...  38.185185
# heart_rate                                               ...
# 36.000000            0          0          0          0  ...          0  \
# 39.321429            0          0          0          0  ...          0
# 49.000000            0          0          0          0  ...          0
# 49.695652            0          0          0          0  ...          0
# 50.250000            0          0          0          0  ...          0
# ...                ...        ...        ...        ...  ...        ...
# 125.769231           0          0          0          0  ...          0
# 126.379310           0          0          0          0  ...          0
# 133.068965           0          0          0          0  ...          0
# 134.565217           0          0          0          0  ...          0
# 135.708333           0          0          0          0  ...          0
#
# temperature  38.246914  38.250000  38.277778  38.346154  38.365079  38.413580
# heart_rate
# 36.000000            0          0          0          0          0          0  \
# 39.321429            0          0          0          0          0          0
# 49.000000            0          0          0          0          0          0
# 49.695652            0          0          0          0          0          0
# 50.250000            0          0          0          0          0          0
# ...                ...        ...        ...        ...        ...        ...
# 125.769231           0          0          0          0          0          0
# 126.379310           0          0          0          0          0          0
# 133.068965           0          0          0          0          0          0
# 134.565217           0          0          0          0          0          0
# 135.708333           0          0          0          0          0          0
#
# temperature  38.643518  39.087963  39.132478
# heart_rate
# 36.000000            0          0          0
# 39.321429            0          0          0
# 49.000000            0          0          0
# 49.695652            0          0          0
# 50.250000            0          0          0
# ...                ...        ...        ...
# 125.769231           0          0          0
# 126.379310           0          0          0
# 133.068965           0          0          0
# 134.565217           0          0          0
# 135.708333           0          0          0
#
# [683 rows x 537 columns]

# %%
# Histogram
df['BMI'].hist(figsize=(10,5),color='y',alpha=1)
plt.xlabel('Minimum BMI')
plt.ylabel('Maximum BMI')
plt.title('BMI')
# Out:
# Text(0.5, 1.0, 'BMI')

# %%
plt.figure(figsize=(8,4))
plt.hist(df['heart_rate'])
plt.title('Heart Rate')
plt.xlabel('Heart Rate Level')
plt.ylabel('Highest Heart Rate Range')
plt.show()

# %%
plt.figure(figsize=(9,6))
sns.scatterplot(x=df['age'],y=df['PH'], color='r')
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.scatter(df['BMI'],df['glucose'],color='green')

# %%
plt.boxplot(df['BMI'])
plt.show()

# %%
sns.boxplot(df['heart_rate'],color='g')
plt.show()

sns.boxplot(df['BMI'],color='y')
plt.show()

# %%
plt.figure(figsize=(18,10))

plt.subplot(2,3,1)
plt.hist(df['Respiratory_rate'],color='violet')
plt.xlabel('Respiratory Rate')

plt.subplot(2,3,2)
plt.hist(df['PH'],color='chocolate')
plt.xlabel('PH')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(24,7))
sns.stripplot(y=df['outcome'],x=df['age'],ax=ax)
plt.title('Age Wise Patient Results')
plt.show()

# %%
def outcome(df, variable):
    dataframe_pie=df[variable].value_counts()
    ax = dataframe_pie.plot.pie(figsize=(5,5),autopct='%1.2f%%', fontsize=10)
    ax.set_title(variable + ' \n', fontsize = 10)
    return np.round(dataframe_pie/df.shape[0]*100,2)

age(df, 'outcome')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 7
#       4     ax.set_title(variable + ' \n', fontsize = 10)
#       5     return np.round(dataframe_pie/df.shape[0]*100,2)
# ----> 7 age(df, 'outcome')
#
# NameError: name 'age' is not defined

# %%
fig,ax=plt.subplots(figsize=(25,12))
sns.heatmap(df.corr(),ax=ax,annot=True)
